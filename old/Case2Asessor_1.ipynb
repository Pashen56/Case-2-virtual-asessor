# %%
import pandas as pd

sample_submission = pd.read_csv("sample_submission.csv")
data_example = pd.read_csv("data_example.csv")
train_data = pd.read_csv("train_data.csv")

print("\n=====================================sample_submission:=====================================\n")
print(sample_submission)

print("\n=====================================data_example:=====================================\n")
print(data_example)

print("\n====================================train_data:=====================================\n")
print(train_data)
# Out:
# =====================================sample_submission:=====================================
#
#                    hash  Correctness
# 0  -7414006047293242141            0
# 1   3210987722203522575            0
# 2  -6393407802773951698            0
# 3   4883083763232971429            0
# 4  -7928633508113063601            0
# ..                  ...          ...
# 71  4048903089355147400            0
# 72  1491295277717010652            0
# 73 -8366699346511237760            0
# 74 -8599528935261139553            0
# 75 -6391278208555238239            0
#
# [76 rows x 2 columns]
#
# =====================================data_example:=====================================
#
#                                             Question  \
# 0               Что такое архитектура набора команд?
# 1  Какие бывают статусы в чек листе и что они озн...
# 2  Зачем мы тестируем мобильные приложение по гай...
# 3  На чем проводить тестирование важнее всего? (р...
# 4          Какие этапы включает в себя тестирование?
#
#                                               Answer  Correctness  \
# 0                                     Код приложения            0
# 1  В чек-листе бывают статусы: "зелёный", "красны...            0
# 2  Чтобы мобильные приложения становились менее ф...            0
# 3                                   мобильных фермах            0
# 4  Этапы тестирования: придумать название програм...            0
#
#                   Lesson                                            Comment
# 0      process_lection_2                                                NaN
# 1  introduction_lesson_2  \nответ считается частично верным если упомяну...
# 2      process_lection_3                                                NaN
# 3      process_lection_1                                                NaN
# 4  introduction_lesson_1  ответ считается неверным если не упомянуто 3/6...
#
# ====================================train_data:=====================================
#
#                                               Question  \
# 0    Как называется официальный (основной) магазин ...
# 1    С чего рекомендуется начинать пункты? (укажите...
# 2                   Что такое универсальные чек-листы?
# 3                       Назовите критерии качества ПО?
# 4    Проверки в чек-листе бывают с детализацией по ...
# ..                                                 ...
# 220   Возможно ли исчерпывающее (полное тестирование)?
# 221          Какие этапы включает в себя тестирование?
# 222         Что такое матрица совместимости устройств?
# 223  Какие бывают статусы в чек листе и что они озн...
# 224  Как называется официальный (основной) магазин ...
#
#                                                 Answer  Correctness  \
# 0                                    Google App Center            0
# 1    Пункты должны начинаться с числительного или ч...            0
# 2    Можно использовать для тестирования всех возмо...            0
# 3    Качественное ПО определяется наличием красивых...            0
# 4    Под этим понимается, что в чек-листе указывает...            0
# ..                                                 ...          ...
# 220  Полное тестирование возможно для любого проект...            0
# 221  6 этапов тестирования: \n\n1) планирование тес...            1
# 222  Матрица совместимости устройств - это просто д...            0
# 223  В чек-листе бывают статусы: "зелёный", "красны...            0
# 224                                          App Store            0
#
#                     Lesson                                            Comment
# 0        process_lection_3  Если студенты отвечают Samsung Galaxy Store ил...
# 1    introduction_lesson_2                                                NaN
# 2    introduction_lesson_2                                                NaN
# 3    introduction_lesson_1   \n \t\nответ считается неверным если не упомя...
# 4    introduction_lesson_2                                                NaN
# ..                     ...                                                ...
# 220  introduction_lesson_1                                                NaN
# 221  introduction_lesson_1  ответ считается неверным если не упомянуто 3/6...
# 222      process_lection_1                                                NaN
# 223  introduction_lesson_2  \nответ считается частично верным если упомяну...
# 224      process_lection_3  Если студенты отвечают Samsung Galaxy Store ил...
#
# [225 rows x 5 columns]

# %%
import pandas as pd
good = pd.read_csv("train_data.csv")
good.sample(25)
# Out:
#                                               Question  \
# 23   Подходят ли эмулятор и симулятор для отладки п...
# 191    Какими hard skills должен обалдать тестировщик?
# 160                 Что такое чек-лист в тестировании?
# 213                     Назовите критерии качества ПО?
# 2                   Что такое универсальные чек-листы?
# 140  Что означает статус blocked? Дайте развернутый...
# 176                         Что такое тестовые данные?
# 11            Что такое нативные мобильные приложения?
# 62   С чего рекомендуется начинать пункты? (укажите...
# 79                Что такое архитектура набора команд?
# 57   Какие бывают статусы в чек листе и что они озн...
# 53   Перечислите типичные виды, которые применяются...
# 218  Как мы определяем доли рынка для разных мобиль...
# 46   Перечислите типичные виды, которые применяются...
# 149                                     Что такое SDK?
# 65                          Что такое ферма устройств?
# 155   На основе какого документа составляют чек-листы?
# 129                         Что такое тестовые данные?
# 201                              Что такое TestFlight?
# 175                                Что такое крешлоги?
# 61                                 Что такое крешлоги?
# 181  Как мы определяем доли рынка для разных мобиль...
# 109  Зачем мы тестируем мобильные приложение по гай...
# 81    Возможно ли исчерпывающее (полное тестирование)?
# 156  Какие бывают статусы в чек листе и что они озн...
#
#                                                 Answer  Correctness  \
# 23   Симуляторы лучше подходят для отладки, чем эму...            0
# 191  Тестировщик должен быть хорошим поваром, знать...            0
# 160  Чек-лист - это список покупок, который тестиро...            0
# 213  Критерии качества ПО: \n1) функциональность \n...            1
# 2    Можно использовать для тестирования всех возмо...            0
# 140                   blocked — проверка заблокирована            0
# 176  Тестовые данные - это информация, которую разр...            0
# 11   Нативные мобильные приложения - это приложения...            0
# 62                                  С существительного            0
# 79                                      Код приложения            0
# 57   1) passed — успешно пройден\n2) failed — кейс ...            1
# 53   Определение скорости, с которой мобильное устр...            0
# 218  Анализировать рынок с помощью сервисов аналитики.            1
# 46   Исследование влияния цветовой гаммы на эмоцион...            0
# 149  Software Development Kit (SDK) — набор инструм...            1
# 65   Это место, где производят выращивание овощей и...            0
# 155  Чек-листы составляют на основе технического за...            1
# 129  Тестовые данные - это случайные числа и символ...            0
# 201  TestFlight — это место, где мы можем управлять...            1
# 175  Это журналы путешествий людей, которые случайн...            0
# 61   Крэшлоги — это данные о том, что происходило с...            1
# 181  Мы определяем доли рынка, подсчитывая количест...            0
# 109  Это делается просто потому, что нам скучно без...            0
# 81                                            Возможно            0
# 156  passed - это когда проверка прошла на ура, а f...            0
#
#                     Lesson                                            Comment
# 23       process_lection_2     Данные представлены в конспекте в виде таблицы
# 191  introduction_lesson_1   \n \t\nответ считается неверным если не упомя...
# 160  introduction_lesson_2  Несмотря на то, что в лекции указаны примеры с...
# 213  introduction_lesson_1   \n \t\nответ считается неверным если не упомя...
# 2    introduction_lesson_2                                                NaN
# 140  introduction_lesson_2                                                NaN
# 176  introduction_lesson_1                                                NaN
# 11       process_lection_1                                                NaN
# 62   introduction_lesson_2                                                NaN
# 79       process_lection_2                                                NaN
# 57   introduction_lesson_2  \nответ считается частично верным если упомяну...
# 53       process_lection_1  Если упомянуто менее 5/9 видов тестирования - ...
# 218      process_lection_1                                                NaN
# 46       process_lection_1  Если упомянуто менее 5/9 видов тестирования - ...
# 149      process_lection_3                                                NaN
# 65       process_lection_2                                                NaN
# 155  introduction_lesson_2                                                NaN
# 129  introduction_lesson_1                                                NaN
# 201      process_lection_3                                                NaN
# 175      process_lection_1                                                NaN
# 61       process_lection_1                                                NaN
# 181      process_lection_1                                                NaN
# 109      process_lection_3                                                NaN
# 81   introduction_lesson_1                                                NaN
# 156  introduction_lesson_2  \nответ считается частично верным если упомяну...

# %%
rep = good[good.Question == 'Что такое нативные мобильные приложения?'].Answer
if rep.shape[0] > 0:
  print(rep.sample(1).iloc[0])
# Out:
# Нативные мобильные приложения - это приложения, которые могут быть установлены только на одно устройство и не могут быть перенесены на другие.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(good.Question)
matrix_big = vectorizer.transform(good.Question)
print(matrix_big.shape)
# Out:
# (225, 185)

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=185)
svd.fit(matrix_big)
matrix_small = svd.transform(matrix_big)
print(matrix_small.shape)
print(svd.explained_variance_ratio_.sum())
# Out:
# (225, 185)
# 1.0000000000000007

# %%
import numpy as np
from sklearn.neighbors import BallTree
from sklearn.base import BaseEstimator

def softmax(x):
  proba = np.exp(-x)
  return proba / sum(proba)

class NeighborSampler(BaseEstimator):
  def __init__(self, k=5, temperature=1.0):
    self.k = k
    self.temperature = temperature
  def fit(self, X, y):
    self.tree_ = BallTree(X)
    self.y_ = np.array(y)
  def predict(self, X, random_state=None):
    distances, indices = self.tree_.query(X, return_distance=True, k=self.k)
    result = []
    for distance, index in zip(distances, indices):
      result.append(np.random.choice(index, p=softmax(distance * self.temperature)))
    return self.y_[result]

# %%
from sklearn.pipeline import make_pipeline
ns = NeighborSampler()
ns.fit(matrix_small, good.Answer)
pipe = make_pipeline(vectorizer, svd, ns)

# %%
print(pipe.predict(['Какие этапы включает в себя тестирование?']))
# Out:
# ['6 этапов тестирования: \n\n1) планирование тестирования;\n2) анализ требований;\n3) проектирование и реализация тестов;\n5) создание отчётов о ходе и результатах тестирования;\n6) оценка качества объекта тестирования.\n']

# %%
print(pipe.predict(['Назовите критерии качества ПО?']))
# Out:
# ['Качественное ПО определяется наличием красивых кнопок и анимации при клике.']

# %%
# !pip install pytelegrambotapi

# %%
import telebot
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

bot = telebot.TeleBot('')

# Словарь для хранения состояний пользователей
user_states = {}

# Обработчик команд /start и /help
@bot.message_handler(commands=['start', 'help'])
def handle_start_help(message):
    user_id = message.from_user.id
    if user_id not in user_states:
        user_states[user_id] = {}
    # Приветственное сообщение и описание доступных команд
    welcome_message = "Добро пожаловать! Я бот, созданный командой: \"Массив Приматов\" для вопросов и ответов.\n\n"
    welcome_message += "Доступные команды:\n"
    welcome_message += "/start или /help - для начала и подсказки.\n"
    welcome_message += "/question - Спроси у меня интересующий тебя вопрос и получи на него ответ.\n"
    welcome_message += "/answer - Проверим твои знания. Я задам тебе вопрос, а ты постараешься дать на него верный ответ, после твоего ответа, я скажу верный ли ответ ты дал.\n"
    bot.reply_to(message, welcome_message)

# Обработчик команды /stop - завершение диалога
@bot.message_handler(commands=['stop'])
def handle_stop(message):
    user_id = message.from_user.id
    if user_id in user_states:
        del user_states[user_id]
    bot.reply_to(message, "Диалог завершен. Если у тебя возникнут еще вопросы ко мне – обращайся (пиши /start или /help).")

# Обработчик команды /question - спросить вопрос и получить на него ответ
@bot.message_handler(commands=['question'])
def handle_question(message):
    user_id = message.from_user.id
    if user_id not in user_states:
        user_states[user_id] = {}
    user_states[user_id]['state'] = 'question'
    # Получаем случайный вопрос из good и сохраняем его
    question = good.sample(1)['Question'].iloc[0]
    user_states[user_id]['current_question'] = question
    bot.reply_to(message, 'Можешь спросить у меня вопрос по пройденному материалу:')
    user_states[user_id]['last_command'] = 'question'

# Обработчик команды /answer - получить вопрос от бота и дать ответ, дожидаясь вердикта
@bot.message_handler(commands=['answer'])
def handle_answer(message):
    user_id = message.from_user.id
    if user_id not in user_states:
        user_states[user_id] = {}
    state = user_states[user_id].get('state')
    user_states[user_id]['last_command'] = 'answer'
    # Получаем случайный вопрос из good и сохраняем его
    question = good.sample(1)['Question'].iloc[0]
    user_states[user_id]['current_question'] = question
    # Отправляем вопрос пользователю
    bot.reply_to(message, question)
    bot.reply_to(message, "Введи свой ответ:")
    user_states[user_id]['state'] = 'waiting_answer'

# Вычисление косинусного сходства между двумя строками
def compute_similarity(answer1, answer2):
    # Преобразование строк в векторы TF-IDF
    vectorizer = TfidfVectorizer()
    vectorizer.fit([answer1, answer2])
    vector_answer1 = vectorizer.transform([answer1])
    vector_answer2 = vectorizer.transform([answer2])
    # Вычисление косинусного сходства между векторами
    similarity = cosine_similarity(vector_answer1, vector_answer2)
    return similarity[0][0]

# Обработчик всех текстовых сообщений
@bot.message_handler(func=lambda message: True)
def handle_text(message):
    user_id = message.from_user.id
    if user_id not in user_states:
        bot.reply_to(message, "Извини, но я не понял твоего вопроса, пжалуйста начни диалог с команды /start или /help.")
        return
    state = user_states[user_id].get('state')
    last_command = user_states[user_id].get('last_command')
    if state == 'question' and last_command == 'question':
        answer = pipe.predict([message.text.lower()])[0]
        bot.reply_to(message, answer)
        bot.reply_to(message, "Если у тебя остались вопросы - задавай. Если нет - отправь /start или /help.")
    elif state == 'waiting_answer':
      # Получаем последний заданный вопрос
      last_question = user_states[user_id]['current_question']
      # Получаем ответ пользователя
      user_answer = message.text.lower()
      # Получаем список правильных ответов для данного вопроса
      correct_answers = good[good['Question'] == last_question]['Answer'].tolist()
      # Инициализируем переменную для лучшего сходства
      best_similarity = 0
      # Проходим по всем правильным ответам и находим наилучшее сходство
      for correct_answer in correct_answers:
          similarity = compute_similarity(user_answer, correct_answer)
          if similarity > best_similarity:
              best_similarity = similarity
      # Проверяем наилучшее сходство и отправляем соответствующее сообщение
      if best_similarity > 0.5:  # Порог сходства для признания ответа верным
          bot.reply_to(message, "Молодец! Ты ответил верно!")
      else:
          bot.reply_to(message, f"Увы твой ответ неверный. Один из верных ответов: {correct_answers[0]}")

      bot.reply_to(message, "Попробуй ответить на этот вопрос:")
      next_question = good.sample(1)['Question'].iloc[0]
      bot.reply_to(message, next_question)
      bot.reply_to(message, "Введи свой ответ:")
      user_states[user_id]['current_question'] = next_question
      user_states[user_id]['state'] = 'waiting_answer'

      bot.reply_to(message, "Или напиши /stop, если хочешь закончить отвечать.")
      user_states[user_id]['state'] = 'waiting_answer'
    else:
        bot.reply_to(message, "Извини, но я не понял твоего вопроса, пжалуйста начни диалог с команды /start или /help.")

# Запуск бота
bot.polling()
